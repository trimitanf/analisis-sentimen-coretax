# %% [markdown]
# # **Normalization**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# Memanggil data yang berada di Google Drive
df = pd.read_csv('/content/drive/MyDrive/Colab/(1)Hasil_Cleaning.csv', keep_default_na=False)
df.head()
# Out:
# Mounted at /content/drive
#        tanggal                                             ulasan  \
# 0  30 Jan 2025  Kok bisa yah anggaran 1 2T cuma bisa bikin web...
# 1  30 Jan 2025  Baru muji coretax lancar abis itu gak bisa bua...
# 2  29 Jan 2025  Coretax itu mirip sama Tugas Akhir mahasiswa S...
# 3  25 Jan 2025  terpantau hari ini coretax lancar jaya @kring_...
# 4  24 Jan 2025  coretax gak jelas. ngehambat semua orang buat ...
#
#        username                                           cleaning
# 0        velvsx  kok bisa yah anggaran t cuma bisa bikin web se...
# 1     labakotor  baru muji coretax lancar abis itu gak bisa bua...
# 2    HebatPaijo  coretax itu mirip sama tugas akhir mahasiswa s...
# 3  na7ahachikyu  terpantau hari ini coretax lancar jaya moga ha...
# 4      saturncz  coretax gak jelas ngehambat semua orang buat k...

# %%
# Fungsi untuk memuat kamus slang
def load_slang_dictionary(file_path):
    # Membaca kamus slang dari file Excel
    df = pd.read_csv(file_path)
    # Mengubah kamus slang menjadi dictionary
    slang_dict = dict(zip(df['slang'], df['formal']))
    return slang_dict

# Fungsi untuk melakukan normalisasi teks
def normalize_text(text, slang_dict):
    if isinstance(text, str):
        # Memisahkan kata-kata dalam teks
        words = text.split()
        normalized_words = []
        for word in words:
            # Mengganti kata slang dengan kata normal jika ada dalam kamus slang
            normalized_word = slang_dict.get(word.lower(), word)
            normalized_words.append(normalized_word)
        #Menggabungkan kata-kata yang sudah dinormalisasi menjadi teks baru
        normalized_words = [str(word) for word in normalized_words]
        normalized_text = ' '.join(normalized_words)
        return normalized_text
    else:
        return str(text)

# Memuat kamus slang
slang_dict = load_slang_dictionary('/content/drive/MyDrive/Colab/kamus_slangword.csv')

# Normalisasi teks pada kolom 'cleaning'
df['normalization'] = df['cleaning'].apply(lambda x: normalize_text(x, slang_dict))
df.head()
# Out:
#        tanggal                                             ulasan  \
# 0  30 Jan 2025  Kok bisa yah anggaran 1 2T cuma bisa bikin web...
# 1  30 Jan 2025  Baru muji coretax lancar abis itu gak bisa bua...
# 2  29 Jan 2025  Coretax itu mirip sama Tugas Akhir mahasiswa S...
# 3  25 Jan 2025  terpantau hari ini coretax lancar jaya @kring_...
# 4  24 Jan 2025  coretax gak jelas. ngehambat semua orang buat ...
#
#        username                                           cleaning  \
# 0        velvsx  kok bisa yah anggaran t cuma bisa bikin web se...
# 1     labakotor  baru muji coretax lancar abis itu gak bisa bua...
# 2    HebatPaijo  coretax itu mirip sama tugas akhir mahasiswa s...
# 3  na7ahachikyu  terpantau hari ini coretax lancar jaya moga ha...
# 4      saturncz  coretax gak jelas ngehambat semua orang buat k...
#
#                                        normalization
# 0  kok bisa ya anggaran t cuma bisa bikin web sem...
# 1  baru muji coretax lancar habis itu enggak bisa...
# 2  coretax itu mirip sama tugas akhir mahasiswa s...
# 3  terpantau hari ini coretax lancar jaya moga ha...
# 4  coretax enggak jelas ngehambat semua orang bua...

# %%
# Cek info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13413 entries, 0 to 13412
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tanggal        13413 non-null  object
#  1   ulasan         13413 non-null  object
#  2   username       13413 non-null  object
#  3   cleaning       13413 non-null  object
#  4   normalization  13413 non-null  object
# dtypes: object(5)
# memory usage: 524.1+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# Simpan ke folder di Google Drive
df.to_csv('/content/drive/MyDrive/Colab/(2)Hasil_Normalization.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
